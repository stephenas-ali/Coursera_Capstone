# %% [markdown]
# <h1>Capstone Project Notebook</h1>
# <p>
#     This notebook will be mainly used for the <b>Capstone Project</b> course on Coursera.
# </p>

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
